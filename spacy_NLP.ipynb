# %% [markdown]
# <a href="https://colab.research.google.com/github/dev-ai-kar/GN22CDBDS001_2113066/blob/main/spacy_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing the necessary libraries
# !pip install textacy
# !python -m spacy download en_core_web_lg
# Out:
# Collecting textacy
#   Downloading textacy-0.11.0-py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 10.9 MB/s
# Collecting pyphen>=0.10.0
#   Downloading pyphen-0.12.0-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 41.6 MB/s
# Collecting jellyfish>=0.8.0
#   Downloading jellyfish-0.9.0.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 54.4 MB/s
# Requirement already satisfied: scikit-learn>=0.19.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.0.2)
# Requirement already satisfied: joblib>=0.13.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.1.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.4.1)
# Requirement already satisfied: cachetools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (4.2.4)
# Collecting cytoolz>=0.10.1
#   Downloading cytoolz-0.11.2.tar.gz (481 kB)
#      |████████████████████████████████| 481 kB 52.2 MB/s
# Requirement already satisfied: tqdm>=4.19.6 in /usr/local/lib/python3.7/dist-packages (from textacy) (4.64.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.21.5)
# Collecting spacy>=3.0.0
#   Downloading spacy-3.2.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 54.2 MB/s
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (2.23.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (2.6.3)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from cytoolz>=0.10.1->textacy) (0.11.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.0->textacy) (3.1.0)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (457 kB)
#      |████████████████████████████████| 457 kB 67.8 MB/s
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 78.1 MB/s
# Collecting typing-extensions<4.0.0.0,>=3.7.4
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.9.1)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.2-py3-none-any.whl (7.2 kB)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (57.4.0)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.8 MB/s
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.15-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (653 kB)
#      |████████████████████████████████| 653 kB 56.2 MB/s
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (21.3)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 49.4 MB/s
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.4.1)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Downloading spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.7-py3-none-any.whl (17 kB)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (7.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy>=3.0.0->textacy) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy>=3.0.0->textacy) (3.0.8)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy>=3.0.0->textacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=3.0.0->textacy) (2.0.1)
# Building wheels for collected packages: cytoolz, jellyfish
#   Building wheel for cytoolz (setup.py) ... done
#   Created wheel for cytoolz: filename=cytoolz-0.11.2-cp37-cp37m-linux_x86_64.whl size=1230826 sha256=bb48ebd1707001428bece8f0c5057a0413834d97e24d044290167cfcf3e003fb
#   Stored in directory: /root/.cache/pip/wheels/38/70/71/ca13ea3d36ccd0b3d0ec7d7a4ca67522048d695b556bba4f59
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp37-cp37m-linux_x86_64.whl size=73971 sha256=8b556c33af10f5209e0ac5c9eaf54bd70f863c67f41a35c526784bff1dcd0dfe
#   Stored in directory: /root/.cache/pip/wheels/fe/99/4e/646ce766df0d070b0ef04db27aa11543e2767fda3075aec31b
# Successfully built cytoolz jellyfish
# Installing collected packages: typing-extensions, catalogue, typer, srsly, pydantic, thinc, spacy-loggers, spacy-legacy, pathy, langcodes, spacy, pyphen, jellyfish, cytoolz, textacy
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# Successfully installed catalogue-2.0.7 cytoolz-0.11.2 jellyfish-0.9.0 langcodes-3.3.0 pathy-0.6.1 pydantic-1.8.2 pyphen-0.12.0 spacy-3.2.4 spacy-legacy-3.0.9 spacy-loggers-1.0.2 srsly-2.4.3 textacy-0.11.0 thinc-8.0.15 typer-0.4.1 typing-extensions-3.10.0.2
# Collecting en-core-web-lg==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.2.0/en_core_web_lg-3.2.0-py3-none-any.whl (777.4 MB)
#      |████████████████████████████████| 777.4 MB 6.6 kB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==3.2.0) (3.2.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (21.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.4.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.4.1)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (7.1.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (8.0.15)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (4.64.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.9.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.4.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.21.5)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.10.0.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.8)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.2.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# !ls
# Out:
# sample_data

# %%
# !touch text.txt

# %%
cat text.txt
# Out:
# The obvious and rational equation is that being trustworthy plus being transparent will lead you to be trusted. Verification of trustworthiness should lead to trust.  This makes sense. Being trustworthy (acting in a way that's worthy of trust) plus being transparent so that people can see your trustworthiness—this should be sufficient.  How then, do we explain that brands like Coke and Google are trusted? The recipe is secret, the algorithm is secret, and competitors like DuckDuckGo certainly act in a more trustworthy way.  In fact, trust often comes from something very different. It's mostly about symbols, expectations and mystery.  Consider the relationship you might enter into if you need surgery. You trust this woman to cut you open, you're putting your life in her hands… without the transparency of seeing all of her surgical statistics, interviewing all previous patients, evaluating her board scores.  Instead, we leap into surgery on the basis of the recommendation from one doctor, on how the office feels, on a few minutes of bedside manner. We walk away from surgery because of a surly receptionist, or a cold demeanor.   The same is true for just about all the food we eat. Not only don't we visit the slaughterhouse or the restaurant kitchen, we make an effort to avoid imagining that they even exist.  In most commercial and organizational engagements, trust is something we want and something we seek out, but we use the most basic semiotics and personal interactions to choose where to place our trust. And once the trust is broken, there's almost no amount of transparency that will help us change our mind.  This is trust from ten thousand years ago, a hangover from a far less complex age when statistical data hadn't been conceived of, when unearthing history was unheard of. But that's now hard-wired into how we judge and are judged.  Quick test: Consider how much you trust Trump, or Clinton, Cruz or Sanders, Scalia or RBG. Is that trust based on transparency? On a rational analysis of public statements and private acts? Or is it more hunch-filled than that? What are the signals and tropes you rely on? Tone of voice? Posture? Appearance? Would more transparency change your mind about someone you trust? What about someone you don't? (Here's a fascinating story on that topic, reconstructed and revealed).  It turns out that we grab trust when we need it, and that rebuilding trust after it's been torn is really quite difficult. Because our expectations (which weren't based on actual data) were shown to be false.  Real trust (even in our modern culture) doesn't always come from divulging, from providing more transparency, but from the actions that people take (or that we think they take) before our eyes. It comes from people who show up before they have to, who help us when they think no one is watching. It comes from people and organizations that play a role that we need them to play.  We trust people based on the hints they give us in their vocal tones, in the stands they take on irrelevant points of view and yes, on what others think.  Mostly, people like us trust people like us.  The mystery that exists in situations without full transparency actually amplifies those feelings.  I'm worried about two real problems, each worse than the other:  a. The trustworthy person or organization that fails to understand or take action on the symbols and mysteries that actually lead to trust, and as a result, fails to make the impact they are capable of.   b. The immoral person or organization who realizes that it's possible to be trusted without actually doing the hard work of being trustworthy.  We may very well be moving toward a world where data is the dominant way we choose to make decisions about trust. In the meantime, the symbols and signals that mesh with our irrational worldviews continue to drive our thinking.

# %%
# Reading the data from file and converting in into suitable form to apply text processing
import spacy
import textacy
dictionary = spacy.load('en_core_web_lg')
f = open('text.txt','rt')
data = f.read()
doc = dictionary(data)
len(doc)
# Out:
# 780

# %%
# Senetence Segmentation
for sentence in doc.sents:
  print(sentence.text)
# Out:
# The obvious and rational equation is that being trustworthy plus being transparent will lead you to be trusted.
# Verification of trustworthiness should lead to trust.
#  This makes sense.
# Being trustworthy (acting in a way that's worthy of trust) plus being transparent so that people can see your trustworthiness—this should be sufficient.
#  How then, do we explain that brands like Coke and Google are trusted?
# The recipe is secret, the algorithm is secret, and competitors like DuckDuckGo certainly act in a more trustworthy way.
#  In fact, trust often comes from something very different.
# It's mostly about symbols, expectations and mystery.
#  Consider the relationship you might enter into if you need surgery.
# You trust this woman to cut you open, you're putting your life in her hands… without the transparency of seeing all of her surgical statistics, interviewing all previous patients, evaluating her board scores.
#  Instead, we leap into surgery on the basis of the recommendation from one doctor, on how the office feels, on a few minutes of bedside manner.
# We walk away from surgery because of a surly receptionist, or a cold demeanor.
#   The same is true for just about all the food we eat.
# Not only don't we visit the slaughterhouse or the restaurant kitchen, we make an effort to avoid imagining that they even exist.
#  In most commercial and organizational engagements, trust is something we want and something we seek out, but we use the most basic semiotics and personal interactions to choose where to place our trust.
# And once the trust is broken, there's almost no amount of transparency that will help us change our mind.
#  This is trust from ten thousand years ago, a hangover from a far less complex age when statistical data hadn't been conceived of, when unearthing history was unheard of.
# But that's now hard-wired into how we judge and are judged.
#  Quick test: Consider how much you trust Trump, or Clinton, Cruz or Sanders, Scalia or RBG.
# Is that trust based on transparency?
# On a rational analysis of public statements and private acts?
# Or is it more hunch-filled than that?
# What are the signals and tropes you rely on?
# Tone of voice?
# Posture?
# Appearance?
# Would more transparency change your mind about someone you trust?
# What about someone you don't?
# (Here's a fascinating story on that topic, reconstructed and revealed).
#  It turns out that we grab trust when we need it, and that rebuilding trust after it's been torn is really quite difficult.
# Because our expectations (which weren't based on actual data) were shown to be false.
#  Real trust (even in our modern culture) doesn't always come from divulging, from providing more transparency, but from the actions that people take (or that we think they take) before our eyes.
# It comes from people who show up before they have to, who help us when they think no one is watching.
# It comes from people and organizations that play a role that we need them to play.
#  We trust people based on the hints they give us in their vocal tones, in the stands they take on irrelevant points of view and yes, on what others think.
#  Mostly, people like us trust people like us.
#  The mystery that exists in situations without full transparency actually amplifies those feelings.
#  I'm worried about two real problems, each worse than the other:  a. The trustworthy person or organization that fails to understand or take action on the symbols and mysteries that actually lead to trust, and as a result, fails to make the impact they are capable of.
#   b.
# The immoral person or organization who realizes that it's possible to be trusted without actually doing the hard work of being trustworthy.
#  We may very well be moving toward a world where data is the dominant way we choose to make decisions about trust.
# In the meantime, the symbols and signals that mesh with our irrational worldviews continue to drive our thinking.

# %%
# Tokenization
print([token.text for token in doc])
# Out:
# ['The', 'obvious', 'and', 'rational', 'equation', 'is', 'that', 'being', 'trustworthy', 'plus', 'being', 'transparent', 'will', 'lead', 'you', 'to', 'be', 'trusted', '.', 'Verification', 'of', 'trustworthiness', 'should', 'lead', 'to', 'trust', '.', ' ', 'This', 'makes', 'sense', '.', 'Being', 'trustworthy', '(', 'acting', 'in', 'a', 'way', 'that', "'s", 'worthy', 'of', 'trust', ')', 'plus', 'being', 'transparent', 'so', 'that', 'people', 'can', 'see', 'your', 'trustworthiness', '—', 'this', 'should', 'be', 'sufficient', '.', ' ', 'How', 'then', ',', 'do', 'we', 'explain', 'that', 'brands', 'like', 'Coke', 'and', 'Google', 'are', 'trusted', '?', 'The', 'recipe', 'is', 'secret', ',', 'the', 'algorithm', 'is', 'secret', ',', 'and', 'competitors', 'like', 'DuckDuckGo', 'certainly', 'act', 'in', 'a', 'more', 'trustworthy', 'way', '.', ' ', 'In', 'fact', ',', 'trust', 'often', 'comes', 'from', 'something', 'very', 'different', '.', 'It', "'s", 'mostly', 'about', 'symbols', ',', 'expectations', 'and', 'mystery', '.', ' ', 'Consider', 'the', 'relationship', 'you', 'might', 'enter', 'into', 'if', 'you', 'need', 'surgery', '.', 'You', 'trust', 'this', 'woman', 'to', 'cut', 'you', 'open', ',', 'you', "'re", 'putting', 'your', 'life', 'in', 'her', 'hands', '…', 'without', 'the', 'transparency', 'of', 'seeing', 'all', 'of', 'her', 'surgical', 'statistics', ',', 'interviewing', 'all', 'previous', 'patients', ',', 'evaluating', 'her', 'board', 'scores', '.', ' ', 'Instead', ',', 'we', 'leap', 'into', 'surgery', 'on', 'the', 'basis', 'of', 'the', 'recommendation', 'from', 'one', 'doctor', ',', 'on', 'how', 'the', 'office', 'feels', ',', 'on', 'a', 'few', 'minutes', 'of', 'bedside', 'manner', '.', 'We', 'walk', 'away', 'from', 'surgery', 'because', 'of', 'a', 'surly', 'receptionist', ',', 'or', 'a', 'cold', 'demeanor', '.', '  ', 'The', 'same', 'is', 'true', 'for', 'just', 'about', 'all', 'the', 'food', 'we', 'eat', '.', 'Not', 'only', 'do', "n't", 'we', 'visit', 'the', 'slaughterhouse', 'or', 'the', 'restaurant', 'kitchen', ',', 'we', 'make', 'an', 'effort', 'to', 'avoid', 'imagining', 'that', 'they', 'even', 'exist', '.', ' ', 'In', 'most', 'commercial', 'and', 'organizational', 'engagements', ',', 'trust', 'is', 'something', 'we', 'want', 'and', 'something', 'we', 'seek', 'out', ',', 'but', 'we', 'use', 'the', 'most', 'basic', 'semiotics', 'and', 'personal', 'interactions', 'to', 'choose', 'where', 'to', 'place', 'our', 'trust', '.', 'And', 'once', 'the', 'trust', 'is', 'broken', ',', 'there', "'s", 'almost', 'no', 'amount', 'of', 'transparency', 'that', 'will', 'help', 'us', 'change', 'our', 'mind', '.', ' ', 'This', 'is', 'trust', 'from', 'ten', 'thousand', 'years', 'ago', ',', 'a', 'hangover', 'from', 'a', 'far', 'less', 'complex', 'age', 'when', 'statistical', 'data', 'had', "n't", 'been', 'conceived', 'of', ',', 'when', 'unearthing', 'history', 'was', 'unheard', 'of', '.', 'But', 'that', "'s", 'now', 'hard', '-', 'wired', 'into', 'how', 'we', 'judge', 'and', 'are', 'judged', '.', ' ', 'Quick', 'test', ':', 'Consider', 'how', 'much', 'you', 'trust', 'Trump', ',', 'or', 'Clinton', ',', 'Cruz', 'or', 'Sanders', ',', 'Scalia', 'or', 'RBG', '.', 'Is', 'that', 'trust', 'based', 'on', 'transparency', '?', 'On', 'a', 'rational', 'analysis', 'of', 'public', 'statements', 'and', 'private', 'acts', '?', 'Or', 'is', 'it', 'more', 'hunch', '-', 'filled', 'than', 'that', '?', 'What', 'are', 'the', 'signals', 'and', 'tropes', 'you', 'rely', 'on', '?', 'Tone', 'of', 'voice', '?', 'Posture', '?', 'Appearance', '?', 'Would', 'more', 'transparency', 'change', 'your', 'mind', 'about', 'someone', 'you', 'trust', '?', 'What', 'about', 'someone', 'you', 'do', "n't", '?', '(', 'Here', "'s", 'a', 'fascinating', 'story', 'on', 'that', 'topic', ',', 'reconstructed', 'and', 'revealed', ')', '.', ' ', 'It', 'turns', 'out', 'that', 'we', 'grab', 'trust', 'when', 'we', 'need', 'it', ',', 'and', 'that', 'rebuilding', 'trust', 'after', 'it', "'s", 'been', 'torn', 'is ...

# %%
# Part of Speech Tagging
print(f"{'text':{8}} {'POS':{6}} {'TAG':{6}} {'Dep':{6}} {'POS explained':{20}} {'tag explained'} ")
for token in doc:
  print(f'{token.text:{8}} {token.pos_:{6}} {token.tag_:{6}} {token.dep_:{6}} {spacy.explain(token.pos_):{20}} {spacy.explain(token.tag_)}')
# Out:
# text     POS    TAG    Dep    POS explained        tag explained
# The      DET    DT     det    determiner           determiner
# obvious  ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# rational ADJ    JJ     conj   adjective            adjective (English), other noun-modifier (Chinese)
# equation NOUN   NN     nsubj  noun                 noun, singular or mass
# is       AUX    VBZ    ROOT   auxiliary            verb, 3rd person singular present
# that     SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# being    AUX    VBG    csubj  auxiliary            verb, gerund or present participle
# trustworthy ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# plus     CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# being    AUX    VBG    conj   auxiliary            verb, gerund or present participle
# transparent ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# will     AUX    MD     aux    auxiliary            verb, modal auxiliary
# lead     VERB   VB     ccomp  verb                 verb, base form
# you      PRON   PRP    dobj   pronoun              pronoun, personal
# to       PART   TO     aux    particle             infinitival "to"
# be       AUX    VB     auxpass auxiliary            verb, base form
# trusted  VERB   VBN    xcomp  verb                 verb, past participle
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# Verification NOUN   NN     nsubj  noun                 noun, singular or mass
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# trustworthiness NOUN   NN     pobj   noun                 noun, singular or mass
# should   AUX    MD     aux    auxiliary            verb, modal auxiliary
# lead     VERB   VB     ROOT   verb                 verb, base form
# to       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# trust    NOUN   NN     pobj   noun                 noun, singular or mass
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# This     PRON   DT     nsubj  pronoun              determiner
# makes    VERB   VBZ    ROOT   verb                 verb, 3rd person singular present
# sense    NOUN   NN     dobj   noun                 noun, singular or mass
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# Being    AUX    VBG    advcl  auxiliary            verb, gerund or present participle
# trustworthy ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# (        PUNCT  -LRB-  punct  punctuation          left round bracket
# acting   VERB   VBG    advcl  verb                 verb, gerund or present participle
# in       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# a        DET    DT     det    determiner           determiner
# way      NOUN   NN     pobj   noun                 noun, singular or mass
# that     PRON   WDT    nsubj  pronoun              wh-determiner
# 's       AUX    VBZ    relcl  auxiliary            verb, 3rd person singular present
# worthy   ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# trust    NOUN   NN     pobj   noun                 noun, singular or mass
# )        PUNCT  -RRB-  punct  punctuation          right round bracket
# plus     CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# being    AUX    VBG    advcl  auxiliary            verb, gerund or present participle
# transparent ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# so       SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# that     SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# people   NOUN   NNS    nsubj  noun                 noun, plural
# can      AUX    MD     aux    auxiliary            verb, modal auxiliary
# see      VERB   VB     advcl  verb                 verb, base form
# your     PRON   PRP$   poss   pronoun              pronoun, possessive
# trustworthiness NOUN   NN     dobj   noun                 noun, singular or mass
# —        PUNCT  :      punct  punctuation          punctuation mark, colon or ellipsis
# this     PRON   DT     nsubj  pronoun              determiner
# should   AUX    MD     aux    auxiliary            verb, modal auxiliary
# be       AUX    VB     ROOT   auxiliary            verb, base form
# sufficient ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# How      SCONJ  WRB    advmod subordinating conjunction wh-adverb
# then     ADV    RB     advmod adverb               adverb
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# do       AUX    VBP    aux    auxiliary            verb, non-3rd person singular present
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# explain  VERB   VB     ROOT   verb                 verb, base form
# that     SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# brands   NOUN   NNS    nsubjpass noun                 noun, plural
# like     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# Coke     PROPN  NNP    pobj   proper noun          noun, proper singular
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# Google   PROPN  NNP    conj   proper noun          noun, proper singular
# are      AUX    VBP    auxpass auxiliary            verb, non-3rd person singular present
# trusted  VERB   VBN    ccomp  verb                 verb, past participle
# ?        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# The      DET    DT     det    determiner           determiner
# recipe   NOUN   NN     nsubj  noun                 noun, singular or mass
# is       AUX    VBZ    ccomp  auxiliary            verb, 3rd person singular present
# secret   ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# the      DET    DT     det    determiner           determiner
# algorithm NOUN   NN     nsubj  noun                 noun, singular or mass
# is       AUX    VBZ    ROOT   auxiliary            verb, 3rd person singular present
# secret   ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# competitors NOUN   NNS    nsubj  noun                 noun, plural
# like     VERB   VBP    prep   verb                 verb, non-3rd person singular present
# DuckDuckGo PRON   PRP    pobj   pronoun              pronoun, personal
# certainly ADV    RB     advmod adverb               adverb
# act      VERB   VBP    conj   verb                 verb, non-3rd person singular present
# in       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# a        DET    DT     det    determiner           determiner
# more     ADV    RBR    advmod adverb               adverb, comparative
# trustworthy ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# way      NOUN   NN     pobj   noun                 noun, singular or mass
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# In       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# fact     NOUN   NN     pobj   noun                 noun, singular or mass
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# trust    NOUN   NN     nsubj  noun                 noun, singular or mass
# often    ADV    RB     advmod adverb               adverb
# comes    VERB   VBZ    ROOT   verb                 verb, 3rd person singular present
# from     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# something PRON   NN     pobj   pronoun              noun, singular or mass
# very     ADV    RB     advmod adverb               adverb
# different ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# It       PRON   PRP    nsubj  pronoun              pronoun, personal
# 's       AUX    VBZ    ROOT   auxiliary            verb, 3rd person singular present
# mostly   ADV    RB     advmod adverb               adverb
# about    ADP    IN     prep   adposition           conjunction, subordinating or preposition
# symbols  NOUN   NNS    pobj   noun                 noun, plural
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# expectations NOUN   NNS    conj   noun                 noun, plural
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# mystery  NOUN   NN     conj   noun                 noun, singular or mass
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# Consider VERB   VBP    ROOT   verb                 verb, non-3rd person singular present
# the      DET    DT     det    determiner           determiner
# relationship NOUN   NN     dobj   noun                 noun, singular or mass
# you      PRON   PRP    nsubj  pronoun              pronoun, personal
# might    AUX    MD     aux    auxiliary            verb, modal auxiliary
# enter    VERB   VB     relcl  verb                 verb, base form
# into     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# if       SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# you      PRON   PRP    nsubj  pronoun              pronoun, personal
# need     VERB   VBP    advcl  verb                 verb, non-3rd person singular present
# surgery  NOUN   NN     dobj   noun                 noun, singular or mass
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# You      PRON   PRP    nsubj  pronoun              pronoun, personal
# trust    VERB   VBP    ccomp  verb                 verb, non-3rd person singular present
# this     DET    DT     det    determiner           determiner
# woman    NOUN   NN     dobj   noun                 noun, singular or mass
# to       PART   TO     aux    particle             infinitival "to"
# cut      VERB   VB     xcomp  verb                 verb, base form
# you      PRON   PRP    dobj   pronoun              pronoun, personal
# open     ADJ    JJ     oprd   adjective            adjective (English), other noun-modifier (Chinese)
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# you      PRON   PRP    nsubj  pronoun              pronoun, personal
# 're      AUX    VBP    aux    auxiliary            verb, non-3rd person singular present
# putting  VERB   VBG    ROOT   verb                 verb, gerund or present participle
# your     PRON   PRP$   poss   pronoun              pronoun, possessive
# life     NOUN   NN     dobj   noun                 noun, singular or mass
# in       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# her      PRON   PRP$   poss   pronoun              pronoun, possessive
# hands    NOUN   NNS    pobj   noun                 noun, plural
# …        PUNCT  NFP    punct  punctuation          superfluous punctuation
# without  ADP    IN     prep   adposition           conjunction, subordinating or preposition
# the      DET    DT     det    determiner           determiner
# transparency NOUN   NN     pobj   noun                 noun, singular or mass
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# seeing   VERB   VBG    pcomp  verb                 verb, gerund or present participle
# all      PRON   DT     dobj   pronoun              determiner
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# her      PRON   PRP$   poss   pronoun              pronoun, possessive
# surgical ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# statistics NOUN   NNS    pobj   noun                 noun, plural
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# interviewing VERB   VBG    advcl  verb                 verb, gerund or present participle
# all      DET    DT     det    determiner           determiner
# previous ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# patients NOUN   NNS    dobj   noun                 noun, plural
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# evaluating VERB   VBG    advcl  verb                 verb, gerund or present participle
# her      PRON   PRP$   poss   pronoun              pronoun, possessive
# board    NOUN   NN     compound noun                 noun, singular or mass
# scores   NOUN   NNS    dobj   noun                 noun, plural
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# Instead  ADV    RB     advmod adverb               adverb
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# leap     VERB   VBP    ROOT   verb                 verb, non-3rd person singular present
# into     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# surgery  NOUN   NN     pobj   noun                 noun, singular or mass
# on       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# the      DET    DT     det    determiner           determiner
# basis    NOUN   NN     pobj   noun                 noun, singular or mass
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# the      DET    DT     det    determiner           determiner
# recommendation NOUN   NN     pobj   noun                 noun, singular or mass
# from     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# one      NUM    CD     nummod numeral              cardinal number
# doctor   NOUN   NN     pobj   noun                 noun, singular or mass
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# on       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# how      SCONJ  WRB    advmod subordinating conjunction wh-adverb
# the      DET    DT     det    determiner           determiner
# office   NOUN   NN     nsubj  noun                 noun, singular or mass
# feels    VERB   VBZ    pcomp  verb                 verb, 3rd person singular present
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# on       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# a        DET    DT     quantmod determiner           determiner
# few      ADJ    JJ     nummod adjective            adjective (English), other noun-modifier (Chinese)
# minutes  NOUN   NNS    pobj   noun                 noun, plural
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# bedside  NOUN   NN     compound noun                 noun, singular or mass
# manner   NOUN   NN     pobj   noun                 noun, singular or mass
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# We       PRON   PRP    nsubj  pronoun              pronoun, personal
# walk     VERB   VBP    ROOT   verb                 verb, non-3rd person singular present
# away     ADV    RB     advmod adverb               adverb
# from     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# surgery  NOUN   NN     pobj   noun                 noun, singular or mass
# because  SCONJ  IN     prep   subordinating conjunction conjunction, subordinating or preposition
# of       ADP    IN     pcomp  adposition           conjunction, subordinating or preposition
# a        DET    DT     det    determiner           determiner
# surly    ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# receptionist NOUN   NN     pobj   noun                 noun, singular or mass
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# or       CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# a        DET    DT     det    determiner           determiner
# cold     ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# demeanor NOUN   NN     conj   noun                 noun, singular or mass
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# The      DET    DT     det    determiner           determiner
# same     ADJ    JJ     nsubj  adjective            adjective (English), other noun-modifier (Chinese)
# is       AUX    VBZ    ROOT   auxiliary            verb, 3rd person singular present
# true     ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# for      ADP    IN     prep   adposition           conjunction, subordinating or preposition
# just     ADV    RB     advmod adverb               adverb
# about    ADP    IN     advmod adposition           conjunction, subordinating or preposition
# all      DET    PDT    predet determiner           predeterminer
# the      DET    DT     det    determiner           determiner
# food     NOUN   NN     pobj   noun                 noun, singular or mass
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# eat      VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# Not      PART   RB     preconj particle             adverb
# only     ADV    RB     advmod adverb               adverb
# do       AUX    VBP    aux    auxiliary            verb, non-3rd person singular present
# n't      PART   RB     neg    particle             adverb
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# visit    VERB   VB     advcl  verb                 verb, base form
# the      DET    DT     det    determiner           determiner
# slaughterhouse NOUN   NN     dobj   noun                 noun, singular or mass
# or       CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# the      DET    DT     det    determiner           determiner
# restaurant NOUN   NN     compound noun                 noun, singular or mass
# kitchen  NOUN   NN     conj   noun                 noun, singular or mass
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# make     VERB   VBP    ROOT   verb                 verb, non-3rd person singular present
# an       DET    DT     det    determiner           determiner
# effort   NOUN   NN     dobj   noun                 noun, singular or mass
# to       PART   TO     aux    particle             infinitival "to"
# avoid    VERB   VB     acl    verb                 verb, base form
# imagining VERB   VBG    xcomp  verb                 verb, gerund or present participle
# that     SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# they     PRON   PRP    nsubj  pronoun              pronoun, personal
# even     ADV    RB     advmod adverb               adverb
# exist    VERB   VBP    ccomp  verb                 verb, non-3rd person singular present
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# In       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# most     ADJ    JJS    amod   adjective            adjective, superlative
# commercial ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# organizational ADJ    JJ     conj   adjective            adjective (English), other noun-modifier (Chinese)
# engagements NOUN   NNS    pobj   noun                 noun, plural
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# trust    NOUN   NN     nsubj  noun                 noun, singular or mass
# is       AUX    VBZ    ROOT   auxiliary            verb, 3rd person singular present
# something PRON   NN     attr   pronoun              noun, singular or mass
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# want     VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# something PRON   NN     conj   pronoun              noun, singular or mass
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# seek     VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# out      ADP    RP     prt    adposition           adverb, particle
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# but      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# use      VERB   VBP    conj   verb                 verb, non-3rd person singular present
# the      DET    DT     det    determiner           determiner
# most     ADV    RBS    advmod adverb               adverb, superlative
# basic    ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# semiotics NOUN   NNS    dobj   noun                 noun, plural
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# personal ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# interactions NOUN   NNS    conj   noun                 noun, plural
# to       PART   TO     aux    particle             infinitival "to"
# choose   VERB   VB     xcomp  verb                 verb, base form
# where    SCONJ  WRB    advmod subordinating conjunction wh-adverb
# to       PART   TO     aux    particle             infinitival "to"
# place    VERB   VB     xcomp  verb                 verb, base form
# our      PRON   PRP$   poss   pronoun              pronoun, possessive
# trust    NOUN   NN     dobj   noun                 noun, singular or mass
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# And      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# once     SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# the      DET    DT     det    determiner           determiner
# trust    NOUN   NN     nsubjpass noun                 noun, singular or mass
# is       AUX    VBZ    auxpass auxiliary            verb, 3rd person singular present
# broken   VERB   VBN    advcl  verb                 verb, past participle
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# there    PRON   EX     expl   pronoun              existential there
# 's       VERB   VBZ    ROOT   verb                 verb, 3rd person singular present
# almost   ADV    RB     advmod adverb               adverb
# no       PRON   DT     nummod pronoun              determiner
# amount   NOUN   NN     attr   noun                 noun, singular or mass
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# transparency NOUN   NN     pobj   noun                 noun, singular or mass
# that     PRON   WDT    nsubj  pronoun              wh-determiner
# will     AUX    MD     aux    auxiliary            verb, modal auxiliary
# help     VERB   VB     relcl  verb                 verb, base form
# us       PRON   PRP    nsubj  pronoun              pronoun, personal
# change   VERB   VB     ccomp  verb                 verb, base form
# our      PRON   PRP$   poss   pronoun              pronoun, possessive
# mind     NOUN   NN     dobj   noun                 noun, singular or mass
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# This     PRON   DT     nsubj  pronoun              determiner
# is       AUX    VBZ    ROOT   auxiliary            verb, 3rd person singular present
# trust    NOUN   NN     attr   noun                 noun, singular or mass
# from     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# ten      NUM    CD     compound numeral              cardinal number
# thousand NUM    CD     nummod numeral              cardinal number
# years    NOUN   NNS    npadvmod noun                 noun, plural
# ago      ADV    RB     pcomp  adverb               adverb
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# a        DET    DT     det    determiner           determiner
# hangover NOUN   NN     appos  noun                 noun, singular or mass
# from     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# a        DET    DT     det    determiner           determiner
# far      ADV    RB     advmod adverb               adverb
# less     ADV    RBR    advmod adverb               adverb, comparative
# complex  ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# age      NOUN   NN     pobj   noun                 noun, singular or mass
# when     SCONJ  WRB    advmod subordinating conjunction wh-adverb
# statistical ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# data     NOUN   NNS    nsubjpass noun                 noun, plural
# had      AUX    VBD    aux    auxiliary            verb, past tense
# n't      PART   RB     neg    particle             adverb
# been     AUX    VBN    auxpass auxiliary            verb, past participle
# conceived VERB   VBN    advcl  verb                 verb, past participle
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# when     SCONJ  WRB    advmod subordinating conjunction wh-adverb
# unearthing VERB   VBG    csubj  verb                 verb, gerund or present participle
# history  NOUN   NN     dobj   noun                 noun, singular or mass
# was      AUX    VBD    ccomp  auxiliary            verb, past tense
# unheard  ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# But      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# that     PRON   DT     nsubj  pronoun              determiner
# 's       AUX    VBZ    ROOT   auxiliary            verb, 3rd person singular present
# now      ADV    RB     advmod adverb               adverb
# hard     ADV    RB     advmod adverb               adverb
# -        PUNCT  HYPH   punct  punctuation          punctuation mark, hyphen
# wired    ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# into     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# how      SCONJ  WRB    advmod subordinating conjunction wh-adverb
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# judge    VERB   VBP    pcomp  verb                 verb, non-3rd person singular present
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# are      AUX    VBP    auxpass auxiliary            verb, non-3rd person singular present
# judged   VERB   VBN    conj   verb                 verb, past participle
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# Quick    ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# test     NOUN   NN     nsubj  noun                 noun, singular or mass
# :        PUNCT  :      punct  punctuation          punctuation mark, colon or ellipsis
# Consider VERB   VB     ROOT   verb                 verb, base form
# how      SCONJ  WRB    advmod subordinating conjunction wh-adverb
# much     ADJ    JJ     dobj   adjective            adjective (English), other noun-modifier (Chinese)
# you      PRON   PRP    nsubj  pronoun              pronoun, personal
# trust    VERB   VBP    ccomp  verb                 verb, non-3rd person singular present
# Trump    PROPN  NNP    dobj   proper noun          noun, proper singular
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# or       CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# Clinton  PROPN  NNP    conj   proper noun          noun, proper singular
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# Cruz     PROPN  NNP    conj   proper noun          noun, proper singular
# or       CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# Sanders  PROPN  NNP    conj   proper noun          noun, proper singular
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# Scalia   PROPN  NNP    conj   proper noun          noun, proper singular
# or       CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# RBG      PROPN  NNP    conj   proper noun          noun, proper singular
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# Is       AUX    VBZ    ROOT   auxiliary            verb, 3rd person singular present
# that     DET    DT     det    determiner           determiner
# trust    NOUN   NN     nsubj  noun                 noun, singular or mass
# based    VERB   VBN    prep   verb                 verb, past participle
# on       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# transparency NOUN   NN     pobj   noun                 noun, singular or mass
# ?        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# On       ADP    IN     ROOT   adposition           conjunction, subordinating or preposition
# a        DET    DT     det    determiner           determiner
# rational ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# analysis NOUN   NN     pobj   noun                 noun, singular or mass
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# public   ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# statements NOUN   NNS    pobj   noun                 noun, plural
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# private  ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# acts     NOUN   NNS    conj   noun                 noun, plural
# ?        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# Or       CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# is       AUX    VBZ    ROOT   auxiliary            verb, 3rd person singular present
# it       PRON   PRP    nsubj  pronoun              pronoun, personal
# more     ADJ    JJR    advmod adjective            adjective, comparative
# hunch    NOUN   NN     npadvmod noun                 noun, singular or mass
# -        PUNCT  HYPH   punct  punctuation          punctuation mark, hyphen
# filled   VERB   VBN    acomp  verb                 verb, past participle
# than     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# that     PRON   DT     pobj   pronoun              determiner
# ?        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# What     PRON   WP     attr   pronoun              wh-pronoun, personal
# are      AUX    VBP    ROOT   auxiliary            verb, non-3rd person singular present
# the      DET    DT     det    determiner           determiner
# signals  NOUN   NNS    nsubj  noun                 noun, plural
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# tropes   NOUN   NNS    conj   noun                 noun, plural
# you      PRON   PRP    nsubj  pronoun              pronoun, personal
# rely     VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# on       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# ?        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# Tone     NOUN   NN     ROOT   noun                 noun, singular or mass
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# voice    NOUN   NN     pobj   noun                 noun, singular or mass
# ?        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# Posture  NOUN   NN     ROOT   noun                 noun, singular or mass
# ?        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# Appearance NOUN   NN     ROOT   noun                 noun, singular or mass
# ?        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# Would    AUX    MD     aux    auxiliary            verb, modal auxiliary
# more     ADJ    JJR    amod   adjective            adjective, comparative
# transparency NOUN   NN     nsubj  noun                 noun, singular or mass
# change   VERB   VB     ROOT   verb                 verb, base form
# your     PRON   PRP$   poss   pronoun              pronoun, possessive
# mind     NOUN   NN     dobj   noun                 noun, singular or mass
# about    ADP    IN     prep   adposition           conjunction, subordinating or preposition
# someone  PRON   NN     pobj   pronoun              noun, singular or mass
# you      PRON   PRP    nsubj  pronoun              pronoun, personal
# trust    VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# ?        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# What     PRON   WP     dep    pronoun              wh-pronoun, personal
# about    ADP    IN     ROOT   adposition           conjunction, subordinating or preposition
# someone  PRON   NN     pobj   pronoun              noun, singular or mass
# you      PRON   PRP    nsubj  pronoun              pronoun, personal
# do       VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# n't      PART   RB     neg    particle             adverb
# ?        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# (        PUNCT  -LRB-  punct  punctuation          left round bracket
# Here     ADV    RB     advmod adverb               adverb
# 's       AUX    VBZ    ROOT   auxiliary            verb, 3rd person singular present
# a        DET    DT     det    determiner           determiner
# fascinating ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# story    NOUN   NN     nsubj  noun                 noun, singular or mass
# on       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# that     DET    DT     det    determiner           determiner
# topic    NOUN   NN     pobj   noun                 noun, singular or mass
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# reconstructed VERB   VBN    acl    verb                 verb, past participle
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# revealed VERB   VBN    conj   verb                 verb, past participle
# )        PUNCT  -RRB-  punct  punctuation          right round bracket
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# It       PRON   PRP    nsubj  pronoun              pronoun, personal
# turns    VERB   VBZ    ROOT   verb                 verb, 3rd person singular present
# out      ADP    RP     prt    adposition           adverb, particle
# that     SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# grab     VERB   VBP    ccomp  verb                 verb, non-3rd person singular present
# trust    NOUN   NN     dobj   noun                 noun, singular or mass
# when     SCONJ  WRB    advmod subordinating conjunction wh-adverb
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# need     VERB   VBP    advcl  verb                 verb, non-3rd person singular present
# it       PRON   PRP    dobj   pronoun              pronoun, personal
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# that     SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# rebuilding VERB   VBG    csubj  verb                 verb, gerund or present participle
# trust    NOUN   NN     dobj   noun                 noun, singular or mass
# after    SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# it       PRON   PRP    nsubjpass pronoun              pronoun, personal
# 's       AUX    VBZ    auxpass auxiliary            verb, 3rd person singular present
# been     AUX    VBN    auxpass auxiliary            verb, past participle
# torn     VERB   VBN    advcl  verb                 verb, past participle
# is       AUX    VBZ    conj   auxiliary            verb, 3rd person singular present
# really   ADV    RB     advmod adverb               adverb
# quite    ADV    RB     advmod adverb               adverb
# difficult ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# Because  SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# our      PRON   PRP$   poss   pronoun              pronoun, possessive
# expectations NOUN   NNS    nsubjpass noun                 noun, plural
# (        PUNCT  -LRB-  punct  punctuation          left round bracket
# which    PRON   WDT    nsubjpass pronoun              wh-determiner
# were     AUX    VBD    auxpass auxiliary            verb, past tense
# n't      PART   RB     neg    particle             adverb
# based    VERB   VBN    relcl  verb                 verb, past participle
# on       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# actual   ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# data     NOUN   NNS    pobj   noun                 noun, plural
# )        PUNCT  -RRB-  punct  punctuation          right round bracket
# were     AUX    VBD    auxpass auxiliary            verb, past tense
# shown    VERB   VBN    ROOT   verb                 verb, past participle
# to       PART   TO     aux    particle             infinitival "to"
# be       AUX    VB     xcomp  auxiliary            verb, base form
# false    ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# Real     ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# trust    NOUN   NN     nsubj  noun                 noun, singular or mass
# (        PUNCT  -LRB-  punct  punctuation          left round bracket
# even     ADV    RB     advmod adverb               adverb
# in       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# our      PRON   PRP$   poss   pronoun              pronoun, possessive
# modern   ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# culture  NOUN   NN     pobj   noun                 noun, singular or mass
# )        PUNCT  -RRB-  punct  punctuation          right round bracket
# does     AUX    VBZ    aux    auxiliary            verb, 3rd person singular present
# n't      PART   RB     neg    particle             adverb
# always   ADV    RB     advmod adverb               adverb
# come     VERB   VB     ROOT   verb                 verb, base form
# from     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# divulging VERB   VBG    pcomp  verb                 verb, gerund or present participle
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# from     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# providing VERB   VBG    pcomp  verb                 verb, gerund or present participle
# more     ADJ    JJR    amod   adjective            adjective, comparative
# transparency NOUN   NN     dobj   noun                 noun, singular or mass
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# but      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# from     ADP    IN     conj   adposition           conjunction, subordinating or preposition
# the      DET    DT     det    determiner           determiner
# actions  NOUN   NNS    pobj   noun                 noun, plural
# that     PRON   WDT    dobj   pronoun              wh-determiner
# people   NOUN   NNS    nsubj  noun                 noun, plural
# take     VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# (        PUNCT  -LRB-  punct  punctuation          left round bracket
# or       CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# that     SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# think    VERB   VBP    conj   verb                 verb, non-3rd person singular present
# they     PRON   PRP    nsubj  pronoun              pronoun, personal
# take     VERB   VBP    ccomp  verb                 verb, non-3rd person singular present
# )        PUNCT  -RRB-  punct  punctuation          right round bracket
# before   ADP    IN     prep   adposition           conjunction, subordinating or preposition
# our      PRON   PRP$   poss   pronoun              pronoun, possessive
# eyes     NOUN   NNS    pobj   noun                 noun, plural
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# It       PRON   PRP    nsubj  pronoun              pronoun, personal
# comes    VERB   VBZ    ROOT   verb                 verb, 3rd person singular present
# from     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# people   NOUN   NNS    pobj   noun                 noun, plural
# who      PRON   WP     nsubj  pronoun              wh-pronoun, personal
# show     VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# up       ADP    RP     prt    adposition           adverb, particle
# before   SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# they     PRON   PRP    nsubj  pronoun              pronoun, personal
# have     VERB   VBP    advcl  verb                 verb, non-3rd person singular present
# to       PART   TO     xcomp  particle             infinitival "to"
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# who      PRON   WP     nsubj  pronoun              wh-pronoun, personal
# help     VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# us       PRON   PRP    dobj   pronoun              pronoun, personal
# when     SCONJ  WRB    advmod subordinating conjunction wh-adverb
# they     PRON   PRP    nsubj  pronoun              pronoun, personal
# think    VERB   VBP    advcl  verb                 verb, non-3rd person singular present
# no       DET    DT     det    determiner           determiner
# one      NOUN   NN     nsubj  noun                 noun, singular or mass
# is       AUX    VBZ    aux    auxiliary            verb, 3rd person singular present
# watching VERB   VBG    ccomp  verb                 verb, gerund or present participle
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# It       PRON   PRP    nsubj  pronoun              pronoun, personal
# comes    VERB   VBZ    ROOT   verb                 verb, 3rd person singular present
# from     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# people   NOUN   NNS    pobj   noun                 noun, plural
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# organizations NOUN   NNS    conj   noun                 noun, plural
# that     PRON   WDT    nsubj  pronoun              wh-determiner
# play     VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# a        DET    DT     det    determiner           determiner
# role     NOUN   NN     dobj   noun                 noun, singular or mass
# that     PRON   WDT    dobj   pronoun              wh-determiner
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# need     VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# them     PRON   PRP    nsubj  pronoun              pronoun, personal
# to       PART   TO     aux    particle             infinitival "to"
# play     VERB   VB     ccomp  verb                 verb, base form
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# We       PRON   PRP    nsubj  pronoun              pronoun, personal
# trust    VERB   VBP    ROOT   verb                 verb, non-3rd person singular present
# people   NOUN   NNS    dobj   noun                 noun, plural
# based    VERB   VBN    acl    verb                 verb, past participle
# on       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# the      DET    DT     det    determiner           determiner
# hints    NOUN   NNS    pobj   noun                 noun, plural
# they     PRON   PRP    nsubj  pronoun              pronoun, personal
# give     VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# us       PRON   PRP    dobj   pronoun              pronoun, personal
# in       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# their    PRON   PRP$   poss   pronoun              pronoun, possessive
# vocal    ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# tones    NOUN   NNS    pobj   noun                 noun, plural
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# in       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# the      DET    DT     det    determiner           determiner
# stands   NOUN   NNS    pobj   noun                 noun, plural
# they     PRON   PRP    nsubj  pronoun              pronoun, personal
# take     VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# on       ADP    RP     prt    adposition           adverb, particle
# irrelevant ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# points   NOUN   NNS    dobj   noun                 noun, plural
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# view     NOUN   NN     pobj   noun                 noun, singular or mass
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# yes      INTJ   UH     conj   interjection         interjection
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# on       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# what     PRON   WP     dobj   pronoun              wh-pronoun, personal
# others   NOUN   NNS    nsubj  noun                 noun, plural
# think    VERB   VBP    pcomp  verb                 verb, non-3rd person singular present
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# Mostly   ADV    RB     advmod adverb               adverb
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# people   NOUN   NNS    nsubj  noun                 noun, plural
# like     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# us       PRON   PRP    pobj   pronoun              pronoun, personal
# trust    VERB   VBP    ROOT   verb                 verb, non-3rd person singular present
# people   NOUN   NNS    dobj   noun                 noun, plural
# like     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# us       PRON   PRP    pobj   pronoun              pronoun, personal
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# The      DET    DT     det    determiner           determiner
# mystery  NOUN   NN     nsubj  noun                 noun, singular or mass
# that     PRON   WDT    nsubj  pronoun              wh-determiner
# exists   VERB   VBZ    relcl  verb                 verb, 3rd person singular present
# in       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# situations NOUN   NNS    pobj   noun                 noun, plural
# without  ADP    IN     prep   adposition           conjunction, subordinating or preposition
# full     ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# transparency NOUN   NN     pobj   noun                 noun, singular or mass
# actually ADV    RB     advmod adverb               adverb
# amplifies VERB   VBZ    ROOT   verb                 verb, 3rd person singular present
# those    DET    DT     det    determiner           determiner
# feelings NOUN   NNS    dobj   noun                 noun, plural
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# I        PRON   PRP    nsubj  pronoun              pronoun, personal
# 'm       AUX    VBP    ROOT   auxiliary            verb, non-3rd person singular present
# worried  ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# about    ADP    IN     prep   adposition           conjunction, subordinating or preposition
# two      NUM    CD     nummod numeral              cardinal number
# real     ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# problems NOUN   NNS    pobj   noun                 noun, plural
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# each     ADV    RB     advmod adverb               adverb
# worse    ADJ    JJR    amod   adjective            adjective, comparative
# than     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# the      DET    DT     det    determiner           determiner
# other    ADJ    JJ     pobj   adjective            adjective (English), other noun-modifier (Chinese)
# :        PUNCT  :      punct  punctuation          punctuation mark, colon or ellipsis
#          SPACE  _SP    dep    space                whitespace
# a.       NOUN   NN     appos  noun                 noun, singular or mass
# The      DET    DT     det    determiner           determiner
# trustworthy ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# person   NOUN   NN     appos  noun                 noun, singular or mass
# or       CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# organization NOUN   NN     conj   noun                 noun, singular or mass
# that     PRON   WDT    nsubj  pronoun              wh-determiner
# fails    VERB   VBZ    relcl  verb                 verb, 3rd person singular present
# to       PART   TO     aux    particle             infinitival "to"
# understand VERB   VB     xcomp  verb                 verb, base form
# or       CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# take     VERB   VB     conj   verb                 verb, base form
# action   NOUN   NN     dobj   noun                 noun, singular or mass
# on       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# the      DET    DT     det    determiner           determiner
# symbols  NOUN   NNS    pobj   noun                 noun, plural
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# mysteries NOUN   NNS    conj   noun                 noun, plural
# that     PRON   WDT    nsubj  pronoun              wh-determiner
# actually ADV    RB     advmod adverb               adverb
# lead     VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# to       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# trust    NOUN   NN     pobj   noun                 noun, singular or mass
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# as       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# a        DET    DT     det    determiner           determiner
# result   NOUN   NN     pobj   noun                 noun, singular or mass
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# fails    VERB   VBZ    conj   verb                 verb, 3rd person singular present
# to       PART   TO     aux    particle             infinitival "to"
# make     VERB   VB     xcomp  verb                 verb, base form
# the      DET    DT     det    determiner           determiner
# impact   NOUN   NN     dobj   noun                 noun, singular or mass
# they     PRON   PRP    nsubj  pronoun              pronoun, personal
# are      AUX    VBP    relcl  auxiliary            verb, non-3rd person singular present
# capable  ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# b.       PROPN  NNP    punct  proper noun          noun, proper singular
# The      DET    DT     det    determiner           determiner
# immoral  ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# person   NOUN   NN     ROOT   noun                 noun, singular or mass
# or       CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# organization NOUN   NN     conj   noun                 noun, singular or mass
# who      PRON   WP     nsubj  pronoun              wh-pronoun, personal
# realizes VERB   VBZ    relcl  verb                 verb, 3rd person singular present
# that     SCONJ  IN     mark   subordinating conjunction conjunction, subordinating or preposition
# it       PRON   PRP    nsubj  pronoun              pronoun, personal
# 's       AUX    VBZ    ccomp  auxiliary            verb, 3rd person singular present
# possible ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# to       PART   TO     aux    particle             infinitival "to"
# be       AUX    VB     auxpass auxiliary            verb, base form
# trusted  VERB   VBN    xcomp  verb                 verb, past participle
# without  ADP    IN     prep   adposition           conjunction, subordinating or preposition
# actually ADV    RB     advmod adverb               adverb
# doing    VERB   VBG    pcomp  verb                 verb, gerund or present participle
# the      DET    DT     det    determiner           determiner
# hard     ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# work     NOUN   NN     dobj   noun                 noun, singular or mass
# of       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# being    AUX    VBG    pcomp  auxiliary            verb, gerund or present participle
# trustworthy ADJ    JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#          SPACE  _SP    dep    space                whitespace
# We       PRON   PRP    nsubj  pronoun              pronoun, personal
# may      AUX    MD     aux    auxiliary            verb, modal auxiliary
# very     ADV    RB     advmod adverb               adverb
# well     ADV    RB     advmod adverb               adverb
# be       AUX    VB     aux    auxiliary            verb, base form
# moving   VERB   VBG    ROOT   verb                 verb, gerund or present participle
# toward   ADP    IN     prep   adposition           conjunction, subordinating or preposition
# a        DET    DT     det    determiner           determiner
# world    NOUN   NN     pobj   noun                 noun, singular or mass
# where    SCONJ  WRB    advmod subordinating conjunction wh-adverb
# data     NOUN   NNS    nsubj  noun                 noun, plural
# is       AUX    VBZ    relcl  auxiliary            verb, 3rd person singular present
# the      DET    DT     det    determiner           determiner
# dominant ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# way      NOUN   NN     attr   noun                 noun, singular or mass
# we       PRON   PRP    nsubj  pronoun              pronoun, personal
# choose   VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# to       PART   TO     aux    particle             infinitival "to"
# make     VERB   VB     xcomp  verb                 verb, base form
# decisions NOUN   NNS    dobj   noun                 noun, plural
# about    ADP    IN     prep   adposition           conjunction, subordinating or preposition
# trust    NOUN   NN     pobj   noun                 noun, singular or mass
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
# In       ADP    IN     prep   adposition           conjunction, subordinating or preposition
# the      DET    DT     det    determiner           determiner
# meantime NOUN   NN     pobj   noun                 noun, singular or mass
# ,        PUNCT  ,      punct  punctuation          punctuation mark, comma
# the      DET    DT     det    determiner           determiner
# symbols  NOUN   NNS    nsubj  noun                 noun, plural
# and      CCONJ  CC     cc     coordinating conjunction conjunction, coordinating
# signals  NOUN   NNS    conj   noun                 noun, plural
# that     PRON   WDT    nsubj  pronoun              wh-determiner
# mesh     VERB   VBP    relcl  verb                 verb, non-3rd person singular present
# with     ADP    IN     prep   adposition           conjunction, subordinating or preposition
# our      PRON   PRP$   poss   pronoun              pronoun, possessive
# irrational ADJ    JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# worldviews NOUN   NNS    pobj   noun                 noun, plural
# continue VERB   VBP    ROOT   verb                 verb, non-3rd person singular present
# to       PART   TO     aux    particle             infinitival "to"
# drive    VERB   VB     xcomp  verb                 verb, base form
# our      PRON   PRP$   poss   pronoun              pronoun, possessive
# thinking NOUN   NN     dobj   noun                 noun, singular or mass
# .        PUNCT  .      punct  punctuation          punctuation mark, sentence closer
#
#         SPACE  _SP    dep    space                whitespace

# %%
# Lemmatization
for token in doc:
    print(token, token.lemma, token.lemma_)
# Out:
# The 7425985699627899538 the
# obvious 7743306943433510820 obvious
# and 2283656566040971221 and
# rational 3999825356068358286 rational
# equation 4913803591805304302 equation
# is 10382539506755952630 be
# that 4380130941430378203 that
# being 10382539506755952630 be
# trustworthy 9880916818962238683 trustworthy
# plus 2123754640991541914 plus
# being 10382539506755952630 be
# transparent 576505010849631577 transparent
# will 18307573501153647118 will
# lead 82546335403996757 lead
# you 7624161793554793053 you
# to 3791531372978436496 to
# be 10382539506755952630 be
# trusted 10567255989167420995 trust
# . 12646065887601541794 .
# Verification 15553401828607442551 verification
# of 886050111519832510 of
# trustworthiness 4252214217067119993 trustworthiness
# should 10292920167869855674 should
# lead 82546335403996757 lead
# to 3791531372978436496 to
# trust 10567255989167420995 trust
# . 12646065887601541794 .
#   8532415787641010193
# This 1995909169258310477 this
# makes 9614445426764226664 make
# sense 13164634093912748321 sense
# . 12646065887601541794 .
# Being 10382539506755952630 be
# trustworthy 9880916818962238683 trustworthy
# ( 12638816674900267446 (
# acting 4330217062942772869 act
# in 3002984154512732771 in
# a 11901859001352538922 a
# way 6878210874361030284 way
# that 4380130941430378203 that
# 's 10382539506755952630 be
# worthy 877140321047472919 worthy
# of 886050111519832510 of
# trust 10567255989167420995 trust
# ) 3842344029291005339 )
# plus 2123754640991541914 plus
# being 10382539506755952630 be
# transparent 576505010849631577 transparent
# so 9781598966686434415 so
# that 4380130941430378203 that
# people 7593739049417968140 people
# can 6635067063807956629 can
# see 11925638236994514241 see
# your 1572612192562026184 your
# trustworthiness 4252214217067119993 trustworthiness
# — 13657828488461764581 —
# this 1995909169258310477 this
# should 10292920167869855674 should
# be 10382539506755952630 be
# sufficient 7448676634580798508 sufficient
# . 12646065887601541794 .
#   8532415787641010193
# How 16331095434822636218 how
# then 2630753287402592467 then
# , 2593208677638477497 ,
# do 2158845516055552166 do
# we 16064069575701507746 we
# explain 8012976192951462851 explain
# that 4380130941430378203 that
# brands 3827899546313821993 brand
# like 18194338103975822726 like
# Coke 12465199634685117656 Coke
# and 2283656566040971221 and
# Google 11578853341595296054 Google
# are 10382539506755952630 be
# trusted 10567255989167420995 trust
# ? 8205403955989537350 ?
# The 7425985699627899538 the
# recipe 1585960631474375612 recipe
# is 10382539506755952630 be
# secret 12786147107810005657 secret
# , 2593208677638477497 ,
# the 7425985699627899538 the
# algorithm 7002907533488190321 algorithm
# is 10382539506755952630 be
# secret 12786147107810005657 secret
# , 2593208677638477497 ,
# and 2283656566040971221 and
# competitors 11640632925505230379 competitor
# like 18194338103975822726 like
# DuckDuckGo 18011894342969847672 duckduckgo
# certainly 10862518981963428747 certainly
# act 4330217062942772869 act
# in 3002984154512732771 in
# a 11901859001352538922 a
# more 2160362229054775535 more
# trustworthy 9880916818962238683 trustworthy
# way 6878210874361030284 way
# . 12646065887601541794 .
#   8532415787641010193
# In 3002984154512732771 in
# fact 3814049101131682695 fact
# , 2593208677638477497 ,
# trust 10567255989167420995 trust
# often 8603663329082222656 often
# comes 5307304325359566725 come
# from 7831658034963690409 from
# something 17370494668576369452 something
# very 9548244504980166557 very
# different 17379251038783395147 different
# . 12646065887601541794 .
# It 10239237003504588839 it
# 's 10382539506755952630 be
# mostly 11042110576038795586 mostly
# about 942632335873952620 about
# symbols 12916593181544568117 symbol
# , 2593208677638477497 ,
# expectations 14115759321026111728 expectation
# and 2283656566040971221 and
# mystery 8626295335712477701 mystery
# . 12646065887601541794 .
#   8532415787641010193
# Consider 17360727451542821422 consider
# the 7425985699627899538 the
# relationship 3329440288606200168 relationship
# you 7624161793554793053 you
# might 9067754100579305666 might
# enter 10291776383235011035 enter
# into 3278561384161438710 into
# if 12446819118446800910 if
# you 7624161793554793053 you
# need 478886015463313967 need
# surgery 2225283248756634950 surgery
# . 12646065887601541794 .
# You 7624161793554793053 you
# trust 10567255989167420995 trust
# this 1995909169258310477 this
# woman 18308318389743014884 woman
# to 3791531372978436496 to
# cut 757346452858091906 cut
# you 7624161793554793053 you
# open 8092125317261700160 open
# , 2593208677638477497 ,
# you 7624161793554793053 you
# 're 10382539506755952630 be
# putting 11532405253426108718 put
# your 1572612192562026184 your
# life 16477424308483498569 life
# in 3002984154512732771 in
# her 4115755726172261197 her
# hands 10690717480206833971 hand
# … 12034422695025479550 …
# without 4711265942760212190 without
# the 7425985699627899538 the
# transparency 16705303300584719577 transparency
# of 886050111519832510 of
# seeing 11925638236994514241 see
# all 13409319323822384369 all
# of 886050111519832510 of
# her 4115755726172261197 her
# surgical 11107462790820866388 surgical
# statistics 1627048415900757154 statistic
# , 2593208677638477497 ,
# interviewing 14070363061372230176 interview
# all 13409319323822384369 all
# previous 12156979554960747529 previous
# patients 14577208587912523278 patient
# , 2593208677638477497 ,
# evaluating 1381294825394259025 evaluate
# her 4115755726172261197 her
# board 14899812206273857344 board
# scores 274157297702941302 score
# . 12646065887601541794 .
#   8532415787641010193
# Instead 10609121202681709909 instead
# , 2593208677638477497 ,
# we 16064069575701507746 we
# leap 3922089725309989134 leap
# into 3278561384161438710 into
# surgery 2225283248756634950 surgery
# on 5640369432778651323 on
# the 7425985699627899538 the
# basis 5961630028127648735 basis
# of 886050111519832510 of
# the 7425985699627899538 the
# recommendation 17265099187533818744 recommendation
# from 7831658034963690409 from
# one 17454115351911680600 one
# doctor 18058202148154971361 doctor
# , 2593208677638477497 ,
# on 5640369432778651323 on
# how 16331095434822636218 how
# the 7425985699627899538 the
# office 10874922665013127783 office
# feels 5741770584995928333 feel
# , 2593208677638477497 ,
# on 5640369432778651323 on
# a 11901859001352538922 a
# few 11866476999679706272 few
# minutes 11139402979604626973 minute
# of 886050111519832510 of
# bedside 12184514426039658517 bedside
# manner 8079055894618953555 manner
# . 12646065887601541794 .
# We 16064069575701507746 we
# walk 1674876016505392235 walk
# away 15726112966383307120 away
# from 7831658034963690409 from
# surgery 2225283248756634950 surgery
# because 16950148841647037698 because
# of 886050111519832510 of
# a 11901859001352538922 a
# surly 17654072139801142950 surly
# receptionist 1959249382363138731 receptionist
# , 2593208677638477497 ,
# or 3740602843040177340 or
# a 11901859001352538922 a
# cold 3117178197819627377 cold
# demeanor 11703817775334003592 demeanor
# . 12646065887601541794 .
#    12127836336259238092
# The 7425985699627899538 the
# same 7488871353255107396 same
# is 10382539506755952630 be
# true 7434368892455186804 true
# for 16037325823156266367 for
# just 7148522813498185515 just
# about 942632335873952620 about
# all 13409319323822384369 all
# the 7425985699627899538 the
# food 18057327756930201825 food
# we 16064069575701507746 we
# eat 9837207709914848172 eat
# . 12646065887601541794 .
# Not 447765159362469301 not
# only 13398675276606405380 only
# do 2158845516055552166 do
# n't 447765159362469301 not
# we 16064069575701507746 we
# visit 15806774029700244804 visit
# the 7425985699627899538 the
# slaughterhouse 4651643161614818216 slaughterhouse
# or 3740602843040177340 or
# the 7425985699627899538 the
# restaurant 13030476447309488184 restaurant
# kitchen 6411253626924010864 kitchen
# , 2593208677638477497 ,
# we 16064069575701507746 we
# make 9614445426764226664 make
# an 15099054000809333061 an
# effort 16063815365313478483 effort
# to 3791531372978436496 to
# avoid 14748219556489505314 avoid
# imagining 11158042576763907092 imagine
# that 4380130941430378203 that
# they 16875582379069451158 they
# even 17339226045912991082 even
# exist 2808794269826886559 exist
# . 12646065887601541794 .
#   8532415787641010193
# In 3002984154512732771 in
# most 11104729984170784471 most
# commercial 2369086909702694846 commercial
# and 2283656566040971221 and
# organizational 4647796130859403985 organizational
# engagements 10272974437208788339 engagement
# , 2593208677638477497 ,
# trust 10567255989167420995 trust
# is 10382539506755952630 be
# something 17370494668576369452 something
# we 16064069575701507746 we
# want 7597692042947428029 want
# and 2283656566040971221 and
# something 17370494668576369452 something
# we 16064069575701507746 we
# seek 3964910719406958291 seek
# out 1696981056005371314 out
# , 2593208677638477497 ,
# but 14560795576765492085 but
# we 16064069575701507746 we
# use 6873750497785110593 use
# the 7425985699627899538 the
# most 11104729984170784471 most
# basic 2744231088585378001 basic
# semiotics 7702773239777043200 semiotic
# and 2283656566040971221 and
# personal 861244163374911113 personal
# interactions 1728268044719593878 interaction
# to 3791531372978436496 to
# choose 289419744638753225 choose
# where 16318918034475841628 where
# to 3791531372978436496 to
# place 7512738811199700769 place
# our 17577015140245084783 our
# trust 10567255989167420995 trust
# . 12646065887601541794 .
# And 2283656566040971221 and
# once 18381768081115421630 once
# the 7425985699627899538 the
# trust 10567255989167420995 trust
# is 10382539506755952630 be
# broken 5527797886271786622 break
# , 2593208677638477497 ,
# there 2112642640949226496 there
# 's 10382539506755952630 be
# almost 9970931496028849525 almost
# no 13055779130471031426 no
# amount 6437996555066804658 amount
# of 886050111519832510 of
# transparency 16705303300584719577 transparency
# that 4380130941430378203 that
# will 18307573501153647118 will
# help 17461235395181654430 help
# us 16064069575701507746 we
# change 3979101002134440957 change
# our 17577015140245084783 our
# mind 8811887512194128535 mind
# . 12646065887601541794 .
#   8532415787641010193
# This 1995909169258310477 this
# is 10382539506755952630 be
# trust 10567255989167420995 trust
# from 7831658034963690409 from
# ten 7970704286052693043 ten
# thousand 2848708369715101064 thousand
# years 14889849580704678361 year
# ago 18432988265768819336 ago
# , 2593208677638477497 ,
# a 11901859001352538922 a
# hangover 6045189296300503078 hangover
# from 7831658034963690409 from
# a 11901859001352538922 a
# far 6785115870927179060 far
# less 589070940943333110 less
# complex 11125307656307208867 complex
# age 10400321950887182855 age
# when 15807309897752499399 when
# statistical 10378466237013462244 statistical
# data 8931270445620108520 datum
# had 14692702688101715474 have
# n't 447765159362469301 not
# been 10382539506755952630 be
# conceived 7979278925406841641 conceive
# of 886050111519832510 of
# , 2593208677638477497 ,
# when 15807309897752499399 when
# unearthing 13175531642680468826 unearth
# history 6249630248276940353 history
# was 10382539506755952630 be
# unheard 5611114259657125194 unheard
# of 886050111519832510 of
# . 12646065887601541794 .
# But 14560795576765492085 but
# that 4380130941430378203 that
# 's 10382539506755952630 be
# now 17157488710739566268 now
# hard 5791351258821946298 hard
# - 9153284864653046197 -
# wired 4602242153616649429 wired
# into 3278561384161438710 into
# how 16331095434822636218 how
# we 16064069575701507746 we
# judge 13878232464834663324 judge
# and 2283656566040971221 and
# are 10382539506755952630 be
# judged 13878232464834663324 judge
# . 12646065887601541794 .
#   8532415787641010193
# Quick 12442504647632856847 quick
# test 1618900948208871284 test
# : 11532473245541075862 :
# Consider 17360727451542821422 consider
# how 16331095434822636218 how
# much 1935074700818135162 much
# you 7624161793554793053 you
# trust 10567255989167420995 trust
# Trump 1134333841961332695 Trump
# , 2593208677638477497 ,
# or 3740602843040177340 or
# Clinton 15434521323102227106 Clinton
# , 2593208677638477497 ,
# Cruz 3259403098345435274 Cruz
# or 3740602843040177340 or
# Sanders 406127757427896417 Sanders
# , 2593208677638477497 ,
# Scalia 3272003217649463775 Scalia
# or 3740602843040177340 or
# RBG 6250731392748387880 RBG
# . 12646065887601541794 .
# Is 10382539506755952630 be
# that 4380130941430378203 that
# trust 10567255989167420995 trust
# based 4715552063986449646 base
# on 5640369432778651323 on
# transparency 16705303300584719577 transparency
# ? 8205403955989537350 ?
# On 5640369432778651323 on
# a 11901859001352538922 a
# rational 3999825356068358286 rational
# analysis 5753914399162559562 analysis
# of 886050111519832510 of
# public 12612542014536453279 public
# statements 13343511457034852349 statement
# and 2283656566040971221 and
# private 2647242751256194409 private
# acts 4330217062942772869 act
# ? 8205403955989537350 ?
# Or 3740602843040177340 or
# is 10382539506755952630 be
# it 10239237003504588839 it
# more 2160362229054775535 more
# hunch 16410074808067962366 hunch
# - 9153284864653046197 -
# filled 2967419177637544458 fill
# than 10794458019344880855 than
# that 4380130941430378203 that
# ? 8205403955989537350 ?
# What 5865838185239622912 what
# are 10382539506755952630 be
# the 7425985699627899538 the
# signals 6752447803106570616 signal
# and 2283656566040971221 and
# tropes 779647858310204156 trope
# you 7624161793554793053 you
# rely 11351163332715512165 rely
# on 5640369432778651323 on
# ? 8205403955989537350 ?
# Tone 665090814712476250 tone
# of 886050111519832510 of
# voice 257396040179354343 voice
# ? 8205403955989537350 ?
# Posture 9720619925738849505 posture
# ? 8205403955989537350 ?
# Appearance 13538774279161928784 appearance
# ? 8205403955989537350 ?
# Would 6992604926141104606 would
# more 2160362229054775535 more
# transparency 16705303300584719577 transparency
# change 3979101002134440957 change
# your 1572612192562026184 your
# mind 8811887512194128535 mind
# about 942632335873952620 about
# someone 18024645270525013057 someone
# you 7624161793554793053 you
# trust 10567255989167420995 trust
# ? 8205403955989537350 ?
# What 5865838185239622912 what
# about 942632335873952620 about
# someone 18024645270525013057 someone
# you 7624161793554793053 you
# do 2158845516055552166 do
# n't 447765159362469301 not
# ? 8205403955989537350 ?
# ( 12638816674900267446 (
# Here 411390626470654571 here
# 's 10382539506755952630 be
# a 11901859001352538922 a
# fascinating 18282403664965979103 fascinating
# story 5345497848075657444 story
# on 5640369432778651323 on
# that 4380130941430378203 that
# topic 1247157010092237539 topic
# , 2593208677638477497 ,
# reconstructed 13148257846231412943 reconstruct
# and 2283656566040971221 and
# revealed 1901500303645832245 reveal
# ) 3842344029291005339 )
# . 12646065887601541794 .
#   8532415787641010193
# It 10239237003504588839 it
# turns 7124218691546400199 turn
# out 1696981056005371314 out
# that 4380130941430378203 that
# we 16064069575701507746 we
# grab 10135808551256466279 grab
# trust 10567255989167420995 trust
# when 15807309897752499399 when
# we 16064069575701507746 we
# need 478886015463313967 need
# it 10239237003504588839 it
# , 2593208677638477497 ,
# and 2283656566040971221 and
# that 4380130941430378203 that
# rebuilding 6268770930636940548 rebuild
# trust 10567255989167420995 trust
# after 13428508259213873547 after
# it 10239237003504588839 it
# 's 10382539506755952630 be
# been 10382539506755952630 be
# torn 17956674869450572180 tear
# is 10382539506755952630 be
# really 14653600329166397554 really
# quite 11176473678897442000 quite
# difficult 7358858360747440042 difficult
# . 12646065887601541794 .
# Because 16950148841647037698 because
# our 17577015140245084783 our
# expectations 14115759321026111728 expectation
# ( 12638816674900267446 (
# which 7063653163634019529 which
# were 10382539506755952630 be
# n't 447765159362469301 not
# based 4715552063986449646 base
# on 5640369432778651323 on
# actual 2649145587264012384 actual
# data 8931270445620108520 datum
# ) 3842344029291005339 )
# were 10382539506755952630 be
# shown 1916734850589852068 show
# to 3791531372978436496 to
# be 10382539506755952630 be
# false 17550068587262304638 false
# . 12646065887601541794 .
#   8532415787641010193
# Real 7050692189315705983 real
# trust 10567255989167420995 trust
# ( 12638816674900267446 (
# even 17339226045912991082 even
# in 3002984154512732771 in
# our 17577015140245084783 our
# modern 5512239401927816148 modern
# culture 6807689115566132187 culture
# ) 3842344029291005339 )
# does 2158845516055552166 do
# n't 447765159362469301 not
# always 17471638809377599778 always
# come 5307304325359566725 come
# from 7831658034963690409 from
# divulging 9181655634163986856 divulge
# , 2593208677638477497 ,
# from 7831658034963690409 from
# providing 3805418597433244348 provide
# more 2160362229054775535 more
# transparency 16705303300584719577 transparency
# , 2593208677638477497 ,
# but 14560795576765492085 but
# from 7831658034963690409 from
# the 7425985699627899538 the
# actions 15659840250438241175 action
# that 4380130941430378203 that
# people 7593739049417968140 people
# take 6789454535283781228 take
# ( 12638816674900267446 (
# or 3740602843040177340 or
# that 4380130941430378203 that
# we 16064069575701507746 we
# think 16875814820671380748 think
# they 16875582379069451158 they
# take 6789454535283781228 take
# ) 3842344029291005339 )
# before 11320251846592927908 before
# our 17577015140245084783 our
# eyes 3094151635273811273 eye
# . 12646065887601541794 .
# It 10239237003504588839 it
# comes 5307304325359566725 come
# from 7831658034963690409 from
# people 7593739049417968140 people
# who 3876862883474502309 who
# show 1916734850589852068 show
# up 2199259611705938403 up
# before 11320251846592927908 before
# they 16875582379069451158 they
# have 14692702688101715474 have
# to 3791531372978436496 to
# , 2593208677638477497 ,
# who 3876862883474502309 who
# help 17461235395181654430 help
# us 16064069575701507746 we
# when 15807309897752499399 when
# they 16875582379069451158 they
# think 16875814820671380748 think
# no 13055779130471031426 no
# one 17454115351911680600 one
# is 10382539506755952630 be
# watching 2054481287215635300 watch
# . 12646065887601541794 .
# It 10239237003504588839 it
# comes 5307304325359566725 come
# from 7831658034963690409 from
# people 7593739049417968140 people
# and 2283656566040971221 and
# organizations 15435089905045195647 organization
# that 4380130941430378203 that
# play 8228585124152053988 play
# a 11901859001352538922 a
# role 15289190992820506615 role
# that 4380130941430378203 that
# we 16064069575701507746 we
# need 478886015463313967 need
# them 16875582379069451158 they
# to 3791531372978436496 to
# play 8228585124152053988 play
# . 12646065887601541794 .
#   8532415787641010193
# We 16064069575701507746 we
# trust 10567255989167420995 trust
# people 7593739049417968140 people
# based 4715552063986449646 base
# on 5640369432778651323 on
# the 7425985699627899538 the
# hints 53791335308931571 hint
# they 16875582379069451158 they
# give 11640825575873464194 give
# us 16064069575701507746 we
# in 3002984154512732771 in
# their 4244585616942201722 their
# vocal 7710022859045418119 vocal
# tones 665090814712476250 tone
# , 2593208677638477497 ,
# in 3002984154512732771 in
# the 7425985699627899538 the
# stands 16121235759125543490 stand
# they 16875582379069451158 they
# take 6789454535283781228 take
# on 5640369432778651323 on
# irrelevant 13957324493958755407 irrelevant
# points 15479733260938818482 point
# of 886050111519832510 of
# view 2608925738682777778 view
# and 2283656566040971221 and
# yes 12731191880880189974 yes
# , 2593208677638477497 ,
# on 5640369432778651323 on
# what 5865838185239622912 what
# others 1176656782636220709 other
# think 16875814820671380748 think
# . 12646065887601541794 .
#   8532415787641010193
# Mostly 11042110576038795586 mostly
# , 2593208677638477497 ,
# people 7593739049417968140 people
# like 18194338103975822726 like
# us 16064069575701507746 we
# trust 10567255989167420995 trust
# people 7593739049417968140 people
# like 18194338103975822726 like
# us 16064069575701507746 we
# . 12646065887601541794 .
#   8532415787641010193
# The 7425985699627899538 the
# mystery 8626295335712477701 mystery
# that 4380130941430378203 that
# exists 2808794269826886559 exist
# in 3002984154512732771 in
# situations 13467163215399432703 situation
# without 4711265942760212190 without
# full 6605652555683495965 full
# transparency 16705303300584719577 transparency
# actually 11882120564994168090 actually
# amplifies 10958600118657112899 amplify
# those 5224941539530611462 those
# feelings 15873186554868950905 feeling
# . 12646065887601541794 .
#   8532415787641010193
# I 4690420944186131903 I
# 'm 10382539506755952630 be
# worried 1590835026366056004 worried
# about 942632335873952620 about
# two 11711838292424000352 two
# real 7050692189315705983 real
# problems 4473158105997569131 problem
# , 2593208677638477497 ,
# each 5379624210385286023 each
# worse 12342627399458421040 bad
# than 10794458019344880855 than
# the 7425985699627899538 the
# other 1176656782636220709 other
# : 11532473245541075862 :
#   8532415787641010193
# a. 11772849645860981237 a.
# The 7425985699627899538 the
# trustworthy 9880916818962238683 trustworthy
# person 14800503047316267216 person
# or 3740602843040177340 or
# organization 15435089905045195647 organization
# that 4380130941430378203 that
# fails 3142894986720291236 fail
# to 3791531372978436496 to
# understand 2256871070683278179 understand
# or 3740602843040177340 or
# take 6789454535283781228 take
# action 15659840250438241175 action
# on 5640369432778651323 on
# the 7425985699627899538 the
# symbols 12916593181544568117 symbol
# and 2283656566040971221 and
# mysteries 8626295335712477701 mystery
# that 4380130941430378203 that
# actually 11882120564994168090 actually
# lead 82546335403996757 lead
# to 3791531372978436496 to
# trust 10567255989167420995 trust
# , 2593208677638477497 ,
# and 2283656566040971221 and
# as 7437575085468336610 as
# a 11901859001352538922 a
# result 16479863421078305451 result
# , 2593208677638477497 ,
# fails 3142894986720291236 fail
# to 3791531372978436496 to
# make 9614445426764226664 make
# the 7425985699627899538 the
# impact 10122832419266696032 impact
# they 16875582379069451158 they
# are 10382539506755952630 be
# capable 12525269483840600249 capable
# of 886050111519832510 of
# . 12646065887601541794 .
#    12127836336259238092
# b. 13215729906341848089 b.
# The 7425985699627899538 the
# immoral 13089998702464960017 immoral
# person 14800503047316267216 person
# or 3740602843040177340 or
# organization 15435089905045195647 organization
# who 3876862883474502309 who
# realizes 18389976271543991779 realize
# that 4380130941430378203 that
# it 10239237003504588839 it
# 's 10382539506755952630 be
# possible 1322442146463163273 possible
# to 3791531372978436496 to
# be 10382539506755952630 be
# trusted 10567255989167420995 trust
# without 4711265942760212190 without
# actually 11882120564994168090 actually
# doing 2158845516055552166 do
# the 7425985699627899538 the
# hard 5791351258821946298 hard
# work 10038440415813069799 work
# of 886050111519832510 of
# being 10382539506755952630 be
# trustworthy 9880916818962238683 trustworthy
# . 12646065887601541794 .
#   8532415787641010193
# We 16064069575701507746 we
# may 14378475389916013800 may
# very 9548244504980166557 very
# well 4525988469032889948 well
# be 10382539506755952630 be
# moving 13534686644065735227 move
# toward 9664647946711101580 toward
# a 11901859001352538922 a
# world 1703489418272052182 world
# where 16318918034475841628 where
# data 8931270445620108520 datum
# is 10382539506755952630 be
# the 7425985699627899538 the
# dominant 156631874980969191 dominant
# way 6878210874361030284 way
# we 16064069575701507746 we
# choose 289419744638753225 choose
# to 3791531372978436496 to
# make 9614445426764226664 make
# decisions 5364348271814505298 decision
# about 942632335873952620 about
# trust 10567255989167420995 trust
# . 12646065887601541794 .
# In 3002984154512732771 in
# the 7425985699627899538 the
# meantime 4786430259827841814 meantime
# , 2593208677638477497 ,
# the 7425985699627899538 the
# symbols 12916593181544568117 symbol
# and 2283656566040971221 and
# signals 6752447803106570616 signal
# that 4380130941430378203 that
# mesh 10637844166382605667 mesh
# with 12510949447758279278 with
# our 17577015140245084783 our
# irrational 17919178529136588699 irrational
# worldviews 5607036362636286300 worldview
# continue 7058970474994285413 continue
# to 3791531372978436496 to
# drive 9588452728179957059 drive
# our 17577015140245084783 our
# thinking 10346293177613240481 thinking
# . 12646065887601541794 .
#
#  962983613142996970

# %%
# Stop Words
stopwords = dictionary.Defaults.stop_words

print(len(stopwords))
print(stopwords)

mytokens = []
mywords = []
for token in doc:
  if(token.is_stop == False):
    mytokens.append(token)
    mywords.append(token.text)
doc = dictionary((" ".join(mywords))[:100])

doc
# Out:
# 326
# {'used', 'call', 'therefore', 'whereas', 'itself', 'these', 'if', 'mostly', 'nothing', 'until', 'move', 'against', 'own', 'regarding', 'those', "'ve", 'top', 'seemed', 'rather', 'because', 'keep', 'mine', 'very', 'our', 'full', "'ll", 'from', 'beforehand', 'my', 'however', 'everywhere', 'whenever', 'through', 'becomes', 'being', 'to', 'twelve', 'n‘t', 'due', 'no', 'hence', 'neither', 'even', 'up', 'both', 'five', 'made', 'latterly', 'of', 'sometimes', 'fifteen', 'then', '‘d', 'forty', '’s', 'their', 'along', 'him', 'see', 'still', 'serious', 'other', 'all', 'quite', 're', 'so', 'be', '’d', 'else', 'afterwards', 'should', 'ten', 'as', 'ourselves', 'formerly', 'really', 'do', 'several', 'hereafter', 'for', 'during', 'did', 'whom', 'although', 'whatever', 'hundred', 'may', 'her', 'nobody', 'show', 'between', 'such', 'themselves', 'make', 'them', 'whereafter', 'you', 'ours', 'throughout', 'herself', 'myself', 'noone', 'whither', 'cannot', 'would', '‘ll', 'empty', 'at', 'is', 'before', 'already', 'whether', 'will', 'eleven', 'nine', 'than', 'the', 'most', "'s", 'others', 'whereby', 'say', 'latter', 'together', 'next', 'often', 'has', 'thru', 'enough', 'seems', 'whereupon', 'never', 'seeming', 'take', 'perhaps', 'among', 'everyone', 'twenty', 'once', 'below', 'besides', 'amount', 'an', 'further', 'what', "'d", 'wherein', 'less', 'out', 'first', 'side', 'via', 'same', 'namely', 'that', "'re", 'part', 'sometime', 'many', 'they', 'anything', 'have', 'am', 'could', 'but', 'least', 'it', 'using', 'there', 'eight', 'only', 'always', 'therein', 'been', 'were', 'within', 'became', 'too', 'are', 'above', 'become', 'since', 'six', 'anywhere', 'on', 'some', 'yet', 'into', 'n’t', 'he', 'must', 'two', 'yourself', 'off', 'former', '’ve', 'upon', 'none', 'she', 'over', 'back', 'ca', 'moreover', 'i', 'becoming', '’m', 'a', 'whose', 'after', 'also', '’re', 'where', 'might', '‘re', 'each', 'beside', 'toward', 'either', 'its', 'something', 'third', 'thereby', 'except', 'why', 'more', '‘ve', 'whole', 'by', 'hereby', 'which', 'one', 'across', 'us', 'elsewhere', 'every', 'we', 'please', 'who', 'sixty', 'this', 'fifty', 'thus', 'about', 'onto', 'hereupon', 'whence', '’ll', 'down', 'somehow', 'behind', 'again', 'anyway', 'amongst', 'much', 'yourselves', 'anyhow', 'bottom', 'though', 'give', 'any', 'can', 'few', 'had', 'your', 'meanwhile', 'not', 'doing', 'name', 'himself', '‘s', 'me', 'last', '‘m', 'per', 'front', 'without', 'nor', 'somewhere', 'was', 'with', 'under', 'nowhere', 'now', 'while', "n't", 'when', 'go', 'whoever', 'around', 'here', 'four', 'indeed', 'hers', 'another', 'unless', 'does', 'well', 'beyond', 'done', 'thence', 'in', 'get', "'m", 'seem', 'thereafter', 'three', 'alone', 'anyone', 'wherever', 'just', 'various', 'how', 'herein', 'his', 'yours', 'nevertheless', 'or', 'and', 'everything', 'otherwise', 'towards', 'someone', 'put', 'ever', 'thereupon', 'almost'}
# obvious rational equation trustworthy plus transparent lead trusted . Verification trustworthiness l

# %%
# Dependency Parsing
from spacy import displacy

displacy.render(doc,jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c79bb602f455497ca33008f5a223df97-0" class="displacy" width="1975" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">obvious</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">rational</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">equation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">trustworthy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">plus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">transparent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">lead</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">trusted .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Verification</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">trustworthiness</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">l</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c79bb602f455497ca33008f5a223df97-0-0" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c79bb602f455497ca33008f5a223df97-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c79bb602f455497ca33008f5a223df97-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c79bb602f455497ca33008f5a223df97-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c79bb602f455497ca33008f5a223df97-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c79bb602f455497ca33008f5a223df97-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,266.5 L573.0,254.5 557.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c79bb602f455497ca33008f5a223df97-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c79bb602f455497ca33008f5a223df97-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c79bb602f455497ca33008f5a223df97-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c79bb602f455497ca33008f5a223df97-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c79bb602f455497ca33008f5a223df97-0-5" stroke-width="2px" d="M420,264.5 C420,2.0 1100.0,2.0 1100.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c79bb602f455497ca33008f5a223df97-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,266.5 L1108.0,254.5 1092.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c79bb602f455497ca33008f5a223df97-0-6" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c79bb602f455497ca33008f5a223df97-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1265.0,266.5 L1273.0,254.5 1257.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c79bb602f455497ca33008f5a223df97-0-7" stroke-width="2px" d="M1470,264.5 C1470,177.0 1615.0,177.0 1615.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c79bb602f455497ca33008f5a223df97-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1470,266.5 L1462,254.5 1478,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c79bb602f455497ca33008f5a223df97-0-8" stroke-width="2px" d="M1645,264.5 C1645,177.0 1790.0,177.0 1790.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" sty

# %%
# Noun Phrases

chunkOfNouns = textacy.extract.noun_chunks(doc, min_freq=3) 
allnounchunks = []
chunkOfNouns = map(str, chunkOfNouns)  
chunkOfNouns = map(str.lower, chunkOfNouns)
for chunk in chunkOfNouns:
  if len(chunk.split(' ')) > 1: 
    allnounchunks.append(chunk)
uniquenounchunks = set(allnounchunks)
uniquenounchunks
# Out:
# set()

# %%
# Named Entity Recognition

def show_ents(doc):
  if doc.ents: 
    for ent in doc.ents: 
      print(ent.text+' - ' +str(ent.start_char) +' - '+ str(ent.end_char) +' - '+ent.label_+ ' - '+str(spacy.explain(ent.label_))) 
  else: 
    print('No named entities found.')
    
show_ents(doc)
# Out:
# No named entities found.

# %% [markdown]
# **Conference Resolution requires latest version of spacy and NeuralCoref. Hence installing following dependencies : **

# %%
# %mkdir new_temp

# %%
ls
# Out:
# new_temp/  sample_data/  text.txt  txt.txt

# %%
# %cd new_temp
# Out:
# /content/new_temp

# %%
# !git clone https://github.com/huggingface/neuralcoref.git
# Out:
# Cloning into 'neuralcoref'...
# remote: Enumerating objects: 772, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 772 (delta 10), reused 5 (delta 1), pack-reused 748
# Receiving objects: 100% (772/772), 67.85 MiB | 8.30 MiB/s, done.
# Resolving deltas: 100% (407/407), done.

# %%
# !pip install -U spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (3.2.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.6.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.3)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.10.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.64.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.6)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.1.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.0.15)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (3.0.8)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)

# %%
# !python -m spacy download en
# Out:
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 6.3 MB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==3.2.0) (3.2.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.15)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.21.5)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.64.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.7)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (7.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.24.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.1)
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# Successfully installed en-core-web-sm-3.2.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# %cd neuralcoref
# Out:
# /content/new_temp/neuralcoref

# %%
# !pip install -r requirements.txt
# Out:
# Collecting spacy<3.0.0,>=2.1.0
#   Downloading spacy-2.3.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.4 MB)
#      |████████████████████████████████| 10.4 MB 16.2 MB/s
# Requirement already satisfied: cython>=0.25 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (0.29.28)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (3.6.4)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp37-cp37m-manylinux2014_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 53.4 MB/s
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (1.21.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (0.4.1)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (184 kB)
#      |████████████████████████████████| 184 kB 62.7 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (57.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (3.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (2.23.0)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (1.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (0.9.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (4.64.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (2.0.6)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.0.0,>=2.1.0->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->-r requirements.txt (line 3)) (8.12.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->-r requirements.txt (line 3)) (21.4.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from pytest->-r requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->-r requirements.txt (line 3)) (1.11.0)
# Installing collected packages: srsly, catalogue, thinc, spacy
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.3
#     Uninstalling srsly-2.4.3:
#       Successfully uninstalled srsly-2.4.3
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.7
#     Uninstalling catalogue-2.0.7:
#       Successfully uninstalled catalogue-2.0.7
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.15
#     Uninstalling thinc-8.0.15:
#       Successfully uninstalled thinc-8.0.15
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.2.4
#     Uninstalling spacy-3.2.4:
#       Successfully uninstalled spacy-3.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# textacy 0.11.0 requires spacy>=3.0.0, but you have spacy 2.3.7 which is incompatible.
# en-core-web-sm 3.2.0 requires spacy<3.3.0,>=3.2.0, but you have spacy 2.3.7 which is incompatible.
# en-core-web-lg 3.2.0 requires spacy<3.3.0,>=3.2.0, but you have spacy 2.3.7 which is incompatible.
# Successfully installed catalogue-1.0.0 spacy-2.3.7 srsly-1.0.5 thinc-7.4.5

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/new_temp/neuralcoref
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from neuralcoref==4.0) (1.21.5)
# Collecting boto3
#   Downloading boto3-1.21.41-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 20.0 MB/s
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from neuralcoref==4.0) (2.23.0)
# Requirement already satisfied: spacy<3.0.0,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from neuralcoref==4.0) (2.3.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref==4.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref==4.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref==4.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref==4.0) (2021.10.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (0.9.1)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (7.4.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (1.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (4.64.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (57.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (2.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (1.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (3.8.0)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.0-py3-none-any.whl (23 kB)
# Collecting botocore<1.25.0,>=1.24.41
#   Downloading botocore-1.24.41-py3-none-any.whl (8.7 MB)
#      |████████████████████████████████| 8.7 MB 38.1 MB/s
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 9.4 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.25.0,>=1.24.41->boto3->neuralcoref==4.0) (2.8.2)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 62.0 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.25.0,>=1.24.41->boto3->neuralcoref==4.0) (1.15.0)
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3, neuralcoref
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Running setup.py develop for neuralcoref
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed boto3-1.21.41 botocore-1.24.41 jmespath-1.0.0 neuralcoref-4.0 s3transfer-0.5.2 urllib3-1.25.11

# %%
# !python -m spacy download en
# Out:
# Collecting en_core_web_sm==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 11.9 MB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.3.1) (2.3.7)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.21.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.6)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (57.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.9.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.64.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.1-py3-none-any.whl size=12047105 sha256=0cfd1e28d832a383d1e2adb86ddd5e25bc80793683b61766fa11dca83689936f
#   Stored in directory: /root/.cache/pip/wheels/b7/0d/f0/7ecae8427c515065d75410989e15e5785dd3975fe06e795cd9
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 3.2.0
#     Uninstalling en-core-web-sm-3.2.0:
#       Successfully uninstalled en-core-web-sm-3.2.0
# Successfully installed en-core-web-sm-2.3.1
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
# Conference Resolution

import neuralcoref
import spacy

nlp = spacy.load('en')
neuralcoref.add_to_pipe(nlp)

f = open('text.txt','rt')
data = f.read()
doc = nlp(data)

def printMentions(doc):
  print('\nAll the mentions in the given text:')
  for cluster in doc._.coref_clusters:
    print(cluster.mentions)

def printPronounReferences(doc):
  print("\nPronuoun and their references")
  for token in doc:
    if token.pos_ == 'PRON' and token._.in_coref:
      for cluster in token._.coref_clusters:
        print(token.text," -> ",cluster.main.text) 

printMentions(doc)
printPronounReferences(doc)
# Out:
# 100%|██████████| 40155833/40155833 [00:00<00:00, 48150525.41B/s]
# All the mentions in the given text:
# [this woman, her, her, her]
# [We, we, we, we, we, we, we, our, us, our, we]
# [the slaughterhouse or the restaurant kitchen, they]
# [our trust, the trust, that trust]
# [we, we]
# [trust, it, it]
# [people, they, they, they, them, they, their, they]
# [we, our, us, we, We, us]
# [us, us]
# [We, we]
# [our, our]
#
# Pronuoun and their references
# We  ->  We
# we  ->  We
# we  ->  We
# we  ->  We
# they  ->  the slaughterhouse or the restaurant kitchen
# we  ->  We
# we  ->  We
# we  ->  We
# us  ->  We
# we  ->  We
# we  ->  we
# we  ->  we
# it  ->  trust
# it  ->  trust
# we  ->  we
# they  ->  people
# they  ->  people
# us  ->  we
# they  ->  people
# we  ->  we
# them  ->  people
# We  ->  we
# they  ->  people
# us  ->  we
# they  ->  people
# us  ->  us
# us  ->  us
# We  ->  We
# we  ->  We
